# %% [markdown]
# <a href="https://colab.research.google.com/github/kjquelal/Xgboost-Clasificacion-WIN-OR-LOSE/blob/main/xgboost_clas_win_or_lose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-19/vb_matches.csv'

# %%
vb_matches=pd.read_csv(url)

# %%
vb_matches
# Out:
#       circuit        tournament        country  year        date gender  \
# 0         AVP  Huntington Beach  United States  2002  2002-05-24      M
# 1         AVP  Huntington Beach  United States  2002  2002-05-24      M
# 2         AVP  Huntington Beach  United States  2002  2002-05-24      M
# 3         AVP  Huntington Beach  United States  2002  2002-05-24      M
# 4         AVP  Huntington Beach  United States  2002  2002-05-24      M
# ...       ...               ...            ...   ...         ...    ...
# 76751    FIVB              Oslo         Norway  2019  2019-08-28      M
# 76752    FIVB              Oslo         Norway  2019  2019-08-28      M
# 76753    FIVB              Oslo         Norway  2019  2019-08-28      M
# 76754    FIVB              Oslo         Norway  2019  2019-08-28      M
# 76755    FIVB              Oslo         Norway  2019  2019-08-28      M
#
#        match_num         w_player1 w_p1_birthdate   w_p1_age  ...  \
# ...
